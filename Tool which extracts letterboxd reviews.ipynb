# %%
import requests
from bs4 import BeautifulSoup


### this finds the number of pages ###
response = requests.get(f"https://letterboxd.com/projector_man/films/by/popular/page/1/")
soup = BeautifulSoup(response.text, 'html.parser')

page_links = []
for link in soup.find_all("a"):
    if "projector_man/films/by/popular/page" in str(link):
        page_links.append(link)
        
contains_last_page_no = str(page_links[-1])

final_page_no = ""
count = 0
while contains_last_page_no[46+count] != "/":
    final_page_no = final_page_no + contains_last_page_no[46+count]
    count += 1
final_page_no = int(final_page_no)
######


print(f"total pages = {final_page_no}")

directory = dict()
over_count = 0


### this counts the number of films in the final page ###
response = requests.get(f"https://letterboxd.com/projector_man/films/by/popular/page/{final_page_no}/")
soup = BeautifulSoup(response.text, 'html.parser')

count_films_last_page = 0

for work in soup.find_all("span", {"class": "frame-title"}):
    count_films_last_page += 1
######


### this is the main loop which downloads the film names and their ratings ###
while over_count < final_page_no:

    over_count += 1
    print(f"pages checked = {over_count}")

    response = requests.get(f"https://letterboxd.com/projector_man/films/by/popular/page/{over_count}/")
    soup = BeautifulSoup(response.text, 'html.parser')
    films = soup.find_all("li")
    
    middle_count = 0
    
    if over_count == final_page_no:
        no_of_films = 72
    else:
        no_of_films = count_films_last_page

    while middle_count < count_films_last_page:

        # this goes through the html and extracts the index of the first tag which contains a review
        for i in films:
            if "film-poster" in str(i):
                first_film_index = films.index(i) + middle_count
                break

        # this is a window which moves along the tag until it reaches the film name
        # not necessary for the review rating because which only needs get_text()
        source = str(films[first_film_index])
        start=0
        end=9
        while True:
            if source[start:end] != 'img alt="':
                start +=1
                end += 1
                continue
            else:
                break
        film_name = ""
        window = source[end]
        count = 0
        while window != '"':
            count += 1
            film_name = film_name+window
            window = source[end+count]

        directory[film_name] = films[first_film_index].get_text().strip()

        middle_count += 1
######
# Out:
# final_page_no = 40
# over count = 1
# over count = 2
# over count = 3
# over count = 4
# over count = 5
# over count = 6
# over count = 7
# over count = 8
# over count = 9
# over count = 10
# over count = 11
# over count = 12
# over count = 13
# over count = 14
# over count = 15
# over count = 16
# over count = 17
# over count = 18
# over count = 19
# over count = 20
# over count = 21
# over count = 22
# over count = 23
# over count = 24
# over count = 25
# over count = 26
# over count = 27
# over count = 28
# over count = 29
# over count = 30
# over count = 31
# over count = 32
# over count = 33
# over count = 34
# over count = 35
# over count = 36
# over count = 37
# over count = 38
# over count = 39
# over count = 40

# %%
directory
# Out:
# {'Parasite': '★★★★½',
#  'Knives Out': '★★★½',
#  'Joker': '★★★',
#  'The Batman': '★★★',
#  'Fight Club': '★★★★',
#  'Pulp Fiction': '★★★★★',
#  'Fantastic Mr. Fox': '★★★★★',
#  'GoodFellas': '★★★★',
#  'Up': '★★★½',
#  'A Quiet Place': '★½',
#  'Marriage Story': '★★★★½',
#  'Titanic': '★★★½',
#  'Split': '★★★½',
#  'The Revenant': '★★★★½',
#  'Fargo': '★★★★★',
#  "Schindler's List": '★★★★½',
#  'The Big Lebowski': '★★★★',
#  'Star Wars: Episode III -\xa0Revenge of the Sith': '★',
#  'Big Hero 6': '★★',
#  'Cruella': '★',
#  'Venom': '★',
#  "One Flew Over the Cuckoo's Nest": '★★★★½',
#  'Room': '★★½',
#  'The Power of the Dog': '★★★½',
#  'The Curious Case of Benjamin Button': '★★★',
#  'Grave of the Fireflies': '★★★★',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb': '★★★★',
#  '21 Jump Street': '★★★',
#  'Frances Ha': '★★★½',
#  'Suspiria': '★★★',
#  'The Disaster Artist': '★★★',
#  'Kick-Ass': '★★',
#  'Swiss Army Man': '★★★',
#  'Jackie Brown': '★★½',
#  'The Father': '★★★★',
#  'Do the Right Thing': '★★★',
#  'Dog Day Afternoon': '★★★★',
#  'Cinema Paradiso': '★★★½',
#  'Glass': '½',
#  'Amadeus': '★★★★',
#  'Halloween': '★½',
#  'Pacific Rim': '★★★',
#  'Under the Silver Lake': '★★★★½',
#  'Hell or High Water': '★★★★',
#  'Belfast': '★★★',
#  'The Place Beyond the Pines': '★★★½',
#  'The Wind Rises': '★★★',
#  'Enter the Void': '★★★★½',
#  'Alien: Covenant': '★★½',
#  'If Beale Street Could Talk': '★★★½',
#  'Thoroughbreds': '★★★½',
#  'Audition': '★★★★★',
#  'Over the Garden Wall': '★★★½',
#  'The Room': '★½',
#  'The Tale of the Princess Kaguya': '★★★',
#  'The Raid': '★★★½',
#  '[REC]': '★★★½',
#  "Buffalo '66": '★★★★',
#  'The Visit': '★',
#  'Lincoln': '★★★',
#  'A Separation': '★★★½',
#  'The Hand of God': '★★★',
#  'Martyrs': '★★★½',
#  'The Good Dinosaur': '★',
#  'Cure': '★★★½',
#  'As Above, So Below': '★★',
#  'Blue Jasmine': '★★★★',
#  'The Gift': '★★',
#  'I Lost My Body': '★★★½',
#  'Ice Age: Dawn of the Dinosaurs': '★★★',
#  'Love': '★★½',
#  "Don't Look Now": '★★★½',
#  'Force Majeure': '★★★★',
#  'Spiral: From the Book of Saw': '½',
#  'Happiness': '★★★½',
#  'Bad Trip': '★★★½',
#  'Selma': '★★★',
#  'A Hidden Life': '★★★½',
#  'Trainwreck': '★★',
#  'Once': '★★★½',
#  'Upstream Color': '★★★★½',
#  "Child's Play": '★',
#  'A Monster Calls': '★★½',
#  'Naked Lunch': '★★★★',
#  'Still Walking': '★★★',
#  'Laurence Anyways': '★★★',
#  'Youth': '★★★★',
#  'Walk Hard: The Dewey Cox Story': '★★★½',
#  'Team America: World Police': '★★★½',
#  'Jigsaw': '★★',
#  'Thunder Road': '★★★★',
#  'Greener Grass': '★★★½',
#  'Macbeth': '★★½',
#  'Obvious Child': '★★★½',
#  'Blair Witch': '½',
#  'Biutiful': '★★★★½',
#  'Smiley Face': '★★★★',
#  'The Diving Bell and the Butterfly': '★★★★★',
#  'Dick Johnson Is Dead': '★★★½',
#  'American Ultra': '★★★',
#  'Happening': '★★★½',
#  'Missing Link': '★★½',
#  'Psycho Goreman': '★½',
#  'Slender Man': '½',
#  'Poetry': '★★★½',
#  'The Chaser': '★★★½',
#  'Phoenix': '★★★½',
#  'The Lake House': '½',
#  'Krisha': '★★★★',
#  'Rachel Getting Married': '★★★',
#  'Samsara': '★★★★',
#  'The Rescue': '★★★½',
#  'Ernest &amp; Celestine': '★★★½',
#  'Lady in the Water': '★★',
#  'Lean on Pete': '★★★★',
#  'Alps': '★★★',
#  'The Death &amp; Life of John F. Donovan': '★★½',
#  'Breathe': '★★★',
#  'Megan Is Missing': '½',
#  'The Dark and the Wicked': '★',
#  'Mississippi Grind': '★★★½',
#  'Frankenhooker': '★★★½',
#  'Dangal': '★★½',
#  'Notes on a Scandal': '★★★',
#  'After the Storm': '★★★½',
#  'Black Christmas': '½',
#  'Birdemic: Shock and Terror': '★',
#  'Kung Pow: Enter the Fist': '★★★★',
#  'Eye in the Sky': '★★½',
#  'Goodbye to Language': '★★★',
#  'The Headless Woman': '★★★',
#  'Death Race 2000': '★★★½',
#  "Ain't Them Bodies Saints": '★★★',
#  'Robot &amp; Frank': '★★★',
#  'Clown': '★★★',
#  'Inside Job': '★★★½',
#  'Tideland': '★★★',
#  'Self/less': '★★½',
#  'Something in the Dirt': '★★★½',
#  'Frantz': '★★½',
#  'White God': '★★★½',
#  'Leviathan': '★★★',
#  "The Strange Color of Your Body's Tears": '★★★',
#  'Rabbit Hole': '★★★',
#  'Mean Creek': '★★★★',
#  'Kaboom': '★★★',
#  'Behind the Curve': '★★★',
#  '16 Blocks': '★★½',
#  '71 Fragments of a Chronology of Chance': '★★★★½',
#  'Hitchcock/Truffaut': '★★★½',
#  'The Third Murder': '★★★½',
#  'Doomsday': '★★½',
#  'Attica': '★★½',
#  'PVT Chat': '★★★½',
#  'Wish I Was Here': '★★',
#  'Running Scared': '★★★½',
#  'Paradise: Love': '★★½',
#  'Electric Boogaloo: The Wild, Untold Story of Cannon Films': '★★★',
#  'Afflicted': '★',
#  'Unrelated': '★★★',
#  'The Eye': '★★★',
#  'Sleepwalk with Me': '★★★',
#  'A Christmas Tale': '★★★½',
#  'Dawson City: Frozen Time': '★★½',
#  'Sunset Song': '★★★',
#  'Best of Enemies': '★★★½',
#  'The Counterfeiters': '★★★½',
#  'Hive': '★★★½',
#  'Yakuza Apocalypse': '★★',
#  'One for the Road': '★★★½',
#  "Tim's Vermeer": '★★★½',
#  'Virunga': '★★★½',
#  'Hannah Arendt': '★★½',
#  'Cabin Fever': '½',
#  'Lingui: The Sacred Bonds': '★★½',
#  'Mistaken for Strangers': '★★★½',
#  "The Devil's Double": '★★½',
#  'The New Girlfriend': '★★★',
#  'Sound of Noise': '★★★½',
#  'My Life Directed by Nicolas Winding Refn': '★★★',
#  'The Witness': '★★½',
#  'Catch the Fair One': '★★★½',
#  'Ai Weiwei: Never Sorry': '★★★½',
#  'Waste Land': '★★★',
#  'Arabian Nights: Volume 1, The Restless One': '★★★½',
#  'Gambit': '★★',
#  'The Mill and the Cross': '★★★½',
#  'Everlasting Moments': '★★★',
#  'Project Nim': '★★★½',
#  'War Witch': '★★★',
#  'Chasing Ice': '★★★½',
#  'From Afar': '★★★',
#  'Armadillo': '★★★★',
#  'White Elephant': '★★★',
#  'The Seasoning House': '★★½',
#  'Man-Thing': '★½',
#  'I-Be Area': '½',
#  'Dirty Wars': '★★★',
#  'The Ambassador': '★★★½',
#  'Clandestine Childhood': '★★★',
#  'Sleeping Giant': '★★½',
#  "I'm Not Ashamed": '½',
#  'Visitors': '★★½',
#  'ThanksKilling 3': '★',
#  'Seasons': '★★★½',
#  'Much Loved': '★★★',
#  'Into Eternity: A Film for the Future': '★★★',
#  'The Clone Returns Home': '★★★',
#  'Happy': '★★½',
#  'Eat That Question: Frank Zappa in His Own Words': '★★★',
#  'Zero Charisma': '★★½',
#  'Fan Girl': '★½',
#  'Hail to the Deadites': '★½',
#  'Kills on Wheels': '★★½',
#  'I Am Not a Hipster': '★★½',
#  'The Union: The Business Behind Getting High': '★★★★',
#  'Going by the Book': '★★½',
#  'Septic Man': '★',
#  'Nobody Has to Know': '★★½',
#  'Paul Dood’s Deadly Lunch Break': '★★½',
#  'Fursonas': '★★★½',
#  'One Floor Below': '★★★',
#  "Porky's Hare Hunt": '★★½',
#  'Lo Invisible': '★★½',
#  'Eden': '★½',
#  'Elefante': '★★★½',
#  'Swallow the Universe': '★★★',
#  'The Blow Out': '★★★½',
#  'Young and Healthy': '★★',
#  'A Crude Awakening': '★★★½',
#  'I Spit Chew on Your Grave': '★★★½',
#  'The Village Smithy': '★★★',
#  'Warsaw Uprising': '★★★',
#  'My Green Fedora': '★★★',
#  "Andy's Rainbow": '½',
#  'The High Level Bridge': '★★',
#  'No Vacancy': '★½',
#  'Generation Rx': '★★★',
#  'Poisoned Lives: Secrets of the Chemical Industry': '★★★',
#  'Guns Along The Bravo': '½'}
